# %%
pip install MetaTrader5
# Out:
# Requirement already satisfied: MetaTrader5 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (5.0.4288)
# Requirement already satisfied: numpy>=1.7 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from MetaTrader5) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import MetaTrader5 as mt5
mt5.initialize()
# Out:
# True

# %%
import pandas as pd
from datetime import datetime, timezone
# Read the CSV file into a DataFrame
df_credentials = pd.read_csv('../../api_credentials.csv') # fetch in root folder of nextcloud

#test
# Print the DataFrame
# for i in range(df.shape[0]):
#     print(df.iloc[i]["Login"])
print(df_credentials)
# Out:
#        Login   Password                 Server                Alias Location  \
# 0     959421  C0nc3pts!  DragonAsiaTech-Server    db_wecopy_trade_1   vps_64
# 1     962558   9Cntkj@J  DragonAsiaTech-Server    db_wecopy_trade_2   vps_97
# 2     962668  C0nc3pts!  DragonAsiaTech-Server  john_wecopy_trade_1   vps_71
# 3    7041022  C0nc3pts!      FPMarketsLLC-Demo                  ASB    VPS64
# 4     635207   6mB!c882        AronMarkets-MT5                  ASB    VPS64
# 5   88750967  C0nc3pts!         Ava-Real 1-MT5                  ASB   vps_64
# 6  110301684   ZSA~hf3D               FBS-Real                  ASB    VPS64
#
#      Type
# 0  funded
# 1  funded
# 2  funded
# 3    demo
# 4    live
# 5    live
# 6    live

# %%
login_list = []
alias_list = []
location_list = []
balance_list = []
equity_list = []
margin_list = []
margin_free_list = []
pnl_list = []
type_list = []

for i in range(df_credentials.shape[0]): # access all rows
    mt5.login(int(df_credentials.iloc[i]["Login"]), df_credentials.iloc[i]["Password"], df_credentials.iloc[i]["Server"]) # login has to be integer otherwise it won't work

    accountInfo = mt5.account_info()
    
    print(accountInfo)

    print("Account: " + str(accountInfo.login))
    print("Balance: " + str(accountInfo.balance))
    print("Equity: " + str(accountInfo.equity))
    print("Profit: " + str(accountInfo.profit))
    print("Free Margin: " + str(accountInfo.margin_free))


    # This is needed to extract server time
    # Define the symbol to fetch the last tick time
    symbol = "BTCUSD_"  # Change this to the symbol you are interested in

    # Request the last tick for the symbol
    last_tick = mt5.symbol_info_tick(symbol)

    # Check if the last tick retrieval was successful
    if last_tick:
        # Retrieve the time of the last tick
        last_tick_time = last_tick.time

        # Convert last tick time from seconds to a datetime object
        last_tick_time_datetime = datetime.fromtimestamp(last_tick_time, timezone.utc)
        print("Server time:", last_tick_time_datetime)
    else:
        print("Failed to retrieve last tick information")
    print("")

    login_list.append(accountInfo.login)
    alias_list.append(df_credentials.iloc[i]["Alias"])
    location_list.append(df_credentials.iloc[i]["Location"])
    balance_list.append(accountInfo.balance)
    equity_list.append(accountInfo.equity)
    margin_list.append(accountInfo.margin)
    margin_free_list.append(accountInfo.margin_free)
    pnl_list.append(accountInfo.equity - accountInfo.balance)
    type_list.append(df_credentials.iloc[i]["Type"])
columns = ["ID", "Name", "Location", "Balance", "Equity", "Margin", "Free Margin", "Floating PnL", "Type"]

df_data = pd.DataFrame(columns=columns)
# print(type_list)

df_data["ID"] = login_list
df_data["Name"] = alias_list
df_data["Location"] = location_list
df_data["Balance"] = balance_list
df_data["Equity"] = equity_list
df_data["Margin"] = margin_list
df_data["Free Margin"] = margin_free_list
df_data["Floating PnL"] = pnl_list
df_data["Type"] = type_list

df_data.to_csv('api_web.csv', index=False, mode='w')


df_data
# Out:
# AccountInfo(login=959421, trade_mode=0, leverage=100, limit_orders=180, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=10619.64, credit=0.0, profit=0.0, equity=10619.64, margin=0.0, margin_free=10619.64, margin_level=0.0, margin_so_call=1.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Dian Basit', server='DragonAsiaTech-Server', currency='USD', company='Dragon Asia Tech Solution LLC')
# Account: 959421
# Balance: 10619.64
# Equity: 10619.64
# Profit: 0.0
# Free Margin: 10619.64
# Failed to retrieve last tick information
#
# AccountInfo(login=962558, trade_mode=0, leverage=100, limit_orders=180, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=9686.11, credit=0.0, profit=0.0, equity=9686.11, margin=0.0, margin_free=9686.11, margin_level=0.0, margin_so_call=1.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Dian Basit', server='DragonAsiaTech-Server', currency='USD', company='Dragon Asia Tech Solution LLC')
# Account: 962558
# Balance: 9686.11
# Equity: 9686.11
# Profit: 0.0
# Free Margin: 9686.11
# Failed to retrieve last tick information
#
# AccountInfo(login=962668, trade_mode=0, leverage=100, limit_orders=180, margin_so_mode=0, trade_allowed=False, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=10004.0, credit=0.0, profit=0.0, equity=0.0, margin=0.0, margin_free=0.0, margin_level=0.0, margin_so_call=1.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='John Saroj Rozario', server='DragonAsiaTech-Server', currency='USD', company='Dragon Asia Tech Solution LLC')
# Account: 962668
# Balance: 10004.0
# Equity: 0.0
# Profit: 0.0
# Free Margin: 0.0
# Server time: 2024-05-11 15:16:57+00:00
#
# AccountInfo(login=7041022, trade_mode=0, leverage=500, limit_orders=0, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=100000.0, credit=0.0, profit=0.0, equity=100000.0, margin=0.0, margin_free=100000.0, margin_level=0.0, margin_so_call=100.0, margin_so_so=50.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Dian Basit 1st A/C ', server='FPMarketsLLC-Demo', currency='USD', company='FP Markets LLC')
# Account: 7041022
# Balance: 100000.0
# Equity: 100000.0
# Profit: 0.0
# Free Margin: 100000.0
# Failed to retrieve last tick information
#
# AccountInfo(login=635207, trade_mode=2, leverage=1000, limit_orders=0, margin_so_mode=0, trade_allowed=True, trade_expert=False, margin_mode=0, currency_digits=2, fifo_close=False, balance=1.88, credit=0.0, profit=0.0, equity=1.88, margin=0.0, margin_free=1.88, margin_level=0.0, margin_so_call=100.0, margin_so_so=50.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Abdul Basit', server='AronMarkets-MT5', currency='USN', company='Aron Markets Ltd')
# Account: 635207
# Balance: 1.88
# Equity: 1.88
# Profit: 0.0
# Free Margin: 1.88
# Failed to retrieve last tick information
#
# AccountInfo(login=88750967, trade_mode=2, leverage=400, limit_orders=0, margin_so_mode=0, trade_allowed=False, trade_expert=False, margin_mode=2, currency_digits=2, fifo_close=False, balance=0.0, credit=0.0, profit=0.0, equity=0.0, margin=0.0, margin_free=0.0, margin_level=0.0, margin_so_call=50.0, margin_so_so=10.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Abdul Basit', server='Ava-Real 1-MT5', currency='CAD', company='Ava Trade Ltd.')
# Account: 88750967
# Balance: 0.0
# Equity: 0.0
# Profit: 0.0
# Free Margin: 0.0
# Failed to retrieve last tick information
#
# AccountInfo(login=110301684, trade_mode=2, leverage=1000, limit_orders=100, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=4155.18, credit=0.0, profit=-27.44, equity=4127.74, margin=129.67, margin_free=3998.07, margin_level=3183.2652116912163, margin_so_call=40.0, margin_so_so=20.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Abdul Salam Basit', server='FBS-Real', currency='USD', company='FBS Markets Inc.')
# Account: 110301684
# Balance: 4155.18
# Equity: 4127.74
# Profit: -27.44
# Free Margin: 3998.07
# Failed to retrieve last tick information
#           ID                 Name Location    Balance     Equity  Margin  \
# 0     959421    db_wecopy_trade_1   vps_64   10619.64   10619.64    0.00
# 1     962558    db_wecopy_trade_2   vps_97    9686.11    9686.11    0.00
# 2     962668  john_wecopy_trade_1   vps_71   10004.00       0.00    0.00
# 3    7041022                  ASB    VPS64  100000.00  100000.00    0.00
# 4     635207                  ASB    VPS64       1.88       1.88    0.00
# 5   88750967                  ASB   vps_64       0.00       0.00    0.00
# 6  110301684                  ASB    VPS64    4155.18    4127.74  129.67
#
#    Free Margin  Floating PnL    Type
# 0     10619.64          0.00  funded
# 1      9686.11          0.00  funded
# 2         0.00     -10004.00  funded
# 3    100000.00          0.00    demo
# 4         1.88          0.00    live
# 5         0.00          0.00    live
# 6      3998.07        -27.44    live
